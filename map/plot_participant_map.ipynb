# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
# read in European polygon and lines as geodataframe
euro_poly_json = './NUTS_RG_20M_2021_4326.geojson'
euro_poly_df = gpd.read_file(euro_poly_json)
euro_lines_json = './NUTS_BN_20M_2021_4326.geojson' 
euro_lines_df = gpd.read_file(euro_lines_json)

# %%
# reproject geodataframe to EPSG 3035 to have non-sqashed Europe
euro_poly_df = euro_poly_df.to_crs('EPSG:3035')
euro_lines_df = euro_lines_df.to_crs('EPSG:3035')

# %%
# choose only country level lines
euro_lines_df = euro_lines_df[euro_lines_df['LEVL_CODE']==0]

# %%
# choose only country level polygons
euro_poly_df = euro_poly_df[euro_poly_df['LEVL_CODE']==0]

# %%
# read participants csv into dataframe
participants_csv = './particpants.csv'
participants_df = pd.read_csv(participants_csv)

# %%
# merge on CNTR_CODE, keep all countries
european_participants_df = pd.merge(euro_poly_df,participants_df, on= 'CNTR_CODE', how='left')
european_participants_df
# Out:
#     id NUTS_ID  LEVL_CODE CNTR_CODE                NAME_LATN  \
# 0   FR      FR          0        FR                   France
# 1   HR      HR          0        HR                 Hrvatska
# 2   HU      HU          0        HU             Magyarország
# 3   AL      AL          0        AL                Shqipëria
# 4   AT      AT          0        AT               Österreich
# 5   BE      BE          0        BE          Belgique/België
# 6   BG      BG          0        BG                 Bulgaria
# 7   CH      CH          0        CH  Schweiz/Suisse/Svizzera
# 8   CY      CY          0        CY                   Kýpros
# 9   CZ      CZ          0        CZ                    Česko
# 10  DE      DE          0        DE              Deutschland
# 11  DK      DK          0        DK                  Danmark
# 12  EE      EE          0        EE                    Eesti
# 13  EL      EL          0        EL                   Elláda
# 14  IE      IE          0        IE             Éire/Ireland
# 15  ES      ES          0        ES                   España
# 16  FI      FI          0        FI            Suomi/Finland
# 17  IS      IS          0        IS                   Ísland
# 18  PT      PT          0        PT                 Portugal
# 19  RO      RO          0        RO                  România
# 20  RS      RS          0        RS                   Serbia
# 21  SE      SE          0        SE                  Sverige
# 22  SI      SI          0        SI                Slovenija
# 23  SK      SK          0        SK                Slovensko
# 24  TR      TR          0        TR                  Türkiye
# 25  UK      UK          0        UK           United Kingdom
# 26  NO      NO          0        NO                    Norge
# 27  IT      IT          0        IT                   Italia
# 28  LI      LI          0        LI            Liechtenstein
# 29  LT      LT          0        LT                  Lietuva
# 30  LU      LU          0        LU               Luxembourg
# 31  LV      LV          0        LV                  Latvija
# 32  ME      ME          0        ME                Crna Gora
# 33  MK      MK          0        MK       Severna Makedonija
# 34  MT      MT          0        MT                    Malta
# 35  NL      NL          0        NL                Nederland
# 36  PL      PL          0        PL                   Polska
#
#                   NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE FID  \
# 0                    France         0.0        NaN           0  FR
# 1                  Hrvatska         0.0        NaN           0  HR
# 2              Magyarország         0.0        NaN           0  HU
# 3                 Shqipëria         0.0        NaN           0  AL
# 4                Österreich         0.0        NaN           0  AT
# 5           Belgique/België         0.0        NaN           0  BE
# 6                  България         0.0        NaN           0  BG
# 7   Schweiz/Suisse/Svizzera         0.0        NaN           0  CH
# 8                    Κύπρος         0.0        NaN           0  CY
# 9                     Česko         0.0        NaN           0  CZ
# 10              Deutschland         0.0        NaN           0  DE
# 11                  Danmark         0.0        NaN           0  DK
# 12                    Eesti         0.0        NaN           0  EE
# 13                   Ελλάδα         0.0        NaN           0  EL
# 14             Éire/Ireland         0.0        NaN           0  IE
# 15                   España         0.0        NaN           0  ES
# 16            Suomi/Finland         0.0        NaN           0  FI
# 17                   Ísland         0.0        NaN           0  IS
# 18                 Portugal         0.0        NaN           0  PT
# 19                  România         0.0        NaN           0  RO
# 20            Srbija/Сpбија         0.0        NaN           0  RS
# 21                  Sverige         0.0        NaN           0  SE
# 22                Slovenija         0.0        NaN           0  SI
# 23                Slovensko         0.0        NaN           0  SK
# 24                  Türkiye         0.0        NaN           0  TR
# 25           United Kingdom         0.0        NaN           0  UK
# 26                    Norge         0.0        NaN           0  NO
# 27                   Italia         0.0        NaN           0  IT
# 28            Liechtenstein         0.0        NaN           0  LI
# 29                  Lietuva         0.0        NaN           0  LT
# 30               Luxembourg         0.0        NaN           0  LU
# 31                  Latvija         0.0        NaN           0  LV
# 32                Црна Гора         0.0        NaN           0  ME
# 33       Северна Македонија         0.0        NaN           0  MK
# 34                    Malta         0.0        NaN           0  MT
# 35                Nederland         0.0        NaN           0  NL
# 36                   Polska         0.0        NaN           0  PL
#
#                                              geometry  Number
# 0   MULTIPOLYGON (((9954235.622 -3059379.353, 9961...     NaN
# 1   MULTIPOLYGON (((4827386.296 2618351.084, 48483...     NaN
# 2   POLYGON ((5214660.279 2880853.697, 5216710.449...     NaN
# 3   POLYGON ((5129579.314 2204099.274, 5148385.521...     NaN
# 4   POLYGON ((4742889.099 2876362.871, 4783217.991...     NaN
# 5   POLYGON ((3957507.060 3167693.957, 3964174.995...     NaN
# 6   POLYGON ((5363358.561 2390534.724, 5395245.448...     NaN
# 7   POLYGON ((4221123.396 2731035.643, 4230515.051...     NaN
# 8   POLYGON ((6342668.984 1629618.630, 6342927.145...     NaN
# 9   POLYGON ((4645979.192 3093184.523, 4656689.626...     NaN
# 10  MULTIPOLYGON (((4264045.977 3530123.270, 42755...    34.0
# 11  MULTIPOLYGON (((4649970.080 3564246.004, 46461...     NaN
# 12  MULTIPOLYGON (((5209290.523 4151085.770, 52115...     NaN
# 13  MULTIPOLYGON (((5933660.634 1621535.788, 59219...     NaN
# 14  MULTIPOLYGON (((3230329.593 3682747.947, 31996...     NaN
# 15  MULTIPOLYGON (((3828319.760 1893179.402, 38317...    17.0
# 16  MULTIPOLYGON (((5073773.587 5207017.965, 50659...    23.0
# 17  POLYGON ((2801938.569 4882218.394, 2796614.357...     8.0
# 18  MULTIPOLYGON (((2822605.079 2261162.917, 28317...     NaN
# 19  POLYGON ((5616141.742 2872864.610, 5661531.567...     NaN
# 20  POLYGON ((5112370.143 2611777.434, 5147917.705...     NaN
# 21  MULTIPOLYGON (((4968500.407 4802688.704, 49724...   167.0
# 22  POLYGON ((4807825.919 2644113.329, 4827386.296...     NaN
# 23  POLYGON ((5038951.091 2947340.783, 5053038.000...     NaN
# 24  MULTIPOLYGON (((6409166.856 2417609.264, 64213...     NaN
# 25  MULTIPOLYGON (((3643416.359 3198789.876, 36397...     NaN
# 26  MULTIPOLYGON (((4754167.467 6382461.291, 47465...   135.0
# 27  MULTIPOLYGON (((4510728.508 2621660.998, 45270...     NaN
# 28  POLYGON ((4281155.972 2659948.040, 4285464.501...     NaN
# 29  POLYGON ((5298223.347 3769132.733, 5303983.109...     NaN
# 30  POLYGON ((4044953.680 3009232.416, 4046925.048...     NaN
# 31  POLYGON ((5350178.114 3949791.201, 5360225.718...     NaN
# 32  POLYGON ((5066457.361 2314658.144, 5106789.717...     NaN
# 33  POLYGON ((5338319.874 2217739.771, 5347082.946...     NaN
# 34  MULTIPOLYGON (((4737037.177 1433526.303, 47322...     NaN
# 35  MULTIPOLYGON (((4113226.651 3371154.602, 41159...     NaN
# 36  POLYGON ((4901276.764 3508415.412, 4926344.394...     NaN

# %%
bounds = euro_lines_df.plot(edgecolor='grey', linewidth = 1)
european_participants_df.plot(column = 'Number', ax=bounds, legend=True)
bounds.set_xlim([2000000,6500000])
bounds.set_ylim([1400000,5500000])
bounds.get_xaxis().set_ticks([])
bounds.get_yaxis().set_ticks([])
# Out:
# []
